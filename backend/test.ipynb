# %%
from langchain_openrouter import ChatOpenRouter
from langchain_nvidia_ai_endpoints import ChatNVIDIA
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
base_llm = ChatOpenRouter(
        model="openai/gpt-oss-120b:free",
        temperature=0.3,
    )
base_llm.invoke("What is AI?")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 5
#       1 base_llm = ChatOpenRouter(
#       2         model="openai/gpt-oss-120b:free",
#       3         temperature=0.3,
#       4     )
# ----> 5 base_llm.invoke("What is AI?")
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
#     476                 stop=stop,
#     477                 callbacks=config.get("callbacks"),
#     478                 tags=config.get("tags"),
#     479                 metadata=config.get("metadata"),
#     480                 run_name=config.get("run_name"),
#     481                 run_id=config.pop("run_id", None),
#     482                 **kwargs,
#     483             ).generations[0][0],
#     484         ).message,
#     485     )
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:1823, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1814 @override
#    1815 def generate_prompt(
#    1816     self,
#    (...)   1820     **kwargs: Any,
#    1821 ) -> LLMResult:
#    1822     prompt_messages = [p.to_messages() for p in prompts]
# -> 1823     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:1630, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1627 for i, m in enumerate(input_messages):
#    1628     try:
#    1629         results.append(
# -> 1630             self._generate_with_cache(
#    1631                 m,
#    1632                 stop=stop,
#    1633                 run_manager=run_managers[i] if run_managers else None,
#    1634                 **kwargs,
#    1635             )
#    1636         )
#    1637     except BaseException as e:
#    1638         if run_managers:
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:1970, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1968     result = generate_from_stream(iter(chunks))
#    1969 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1970     result = self._generate(
#    1971         messages, stop=stop, run_manager=run_manager, **kwargs
#    1972     )
#    1973 else:
#    1974     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_openrouter\chat_models.py:510, in ChatOpenRouter._generate(self, messages, stop, run_manager, **kwargs)
#     508 _strip_internal_kwargs(params)
#     509 sdk_messages = _wrap_messages_for_sdk(message_dicts)
# --> 510 response = self.client.chat.send(messages=sdk_messages, **params)
#     511 return self._create_chat_result(response)
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\openrouter\chat.py:560, in Chat.send(self, messages, http_referer, x_open_router_title, x_open_router_categories, cache_control, debug, frequency_penalty, image_config, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, model, models, parallel_tool_calls, plugins, presence_penalty, provider, reasoning, response_format, seed, service_tier, session_id, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, trace, user, retries, server_url, timeout_ms, http_headers)
#     558 response_data: Any = None
#     559 if utils.match_response(http_res, "200", "application/json"):
# --> 560     http_res_text = utils.stream_to_text(http_res)
#     561     return unmarshal_json_response(
#     562         components.ChatResult, http_res, http_res_text
#     563     )
#     564 if utils.match_response(http_res, "200", "text/event-stream"):
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\openrouter\utils\serializers.py:201, in stream_to_text(stream)
#     200 def stream_to_text(stream: httpx.Response) -> str:
# --> 201     return "".join(stream.iter_text())
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpx\_models.py:916, in Response.iter_text(self, chunk_size)
#     914 chunker = TextChunker(chunk_size=chunk_size)
#     915 with request_context(request=self._request):
# --> 916     for byte_content in self.iter_bytes():
#     917         text_content = decoder.decode(byte_content)
#     918         for chunk in chunker.decode(text_content):
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpx\_models.py:897, in Response.iter_bytes(self, chunk_size)
#     895 chunker = ByteChunker(chunk_size=chunk_size)
#     896 with request_context(request=self._request):
# --> 897     for raw_bytes in self.iter_raw():
#     898         decoded = decoder.decode(raw_bytes)
#     899         for chunk in chunker.decode(decoded):
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpx\_models.py:951, in Response.iter_raw(self, chunk_size)
#     948 chunker = ByteChunker(chunk_size=chunk_size)
#     950 with request_context(request=self._request):
# --> 951     for raw_stream_bytes in self.stream:
#     952         self._num_bytes_downloaded += len(raw_stream_bytes)
#     953         for chunk in chunker.decode(raw_stream_bytes):
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpx\_client.py:153, in BoundSyncStream.__iter__(self)
#     152 def __iter__(self) -> typing.Iterator[bytes]:
# --> 153     for chunk in self._stream:
#     154         yield chunk
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpx\_transports\default.py:127, in ResponseStream.__iter__(self)
#     125 def __iter__(self) -> typing.Iterator[bytes]:
#     126     with map_httpcore_exceptions():
# --> 127         for part in self._httpcore_stream:
#     128             yield part
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpcore\_sync\connection_pool.py:407, in PoolByteStream.__iter__(self)
#     405 except BaseException as exc:
#     406     self.close()
# --> 407     raise exc from None
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpcore\_sync\connection_pool.py:403, in PoolByteStream.__iter__(self)
#     401 def __iter__(self) -> typing.Iterator[bytes]:
#     402     try:
# --> 403         for part in self._stream:
#     404             yield part
#     405     except BaseException as exc:
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpcore\_sync\http11.py:342, in HTTP11ConnectionByteStream.__iter__(self)
#     340 with ShieldCancellation():
#     341     self.close()
# --> 342 raise exc
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpcore\_sync\http11.py:334, in HTTP11ConnectionByteStream.__iter__(self)
#     332 try:
#     333     with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334         for chunk in self._connection._receive_response_body(**kwargs):
#     335             yield chunk
#     336 except BaseException as exc:
#     337     # If we get an exception while streaming the response,
#     338     # we want to close the response (and possibly the connection)
#     339     # before raising that exception.
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpcore\_sync\http11.py:203, in HTTP11Connection._receive_response_body(self, request)
#     200 timeout = timeouts.get("read", None)
#     202 while True:
# --> 203     event = self._receive_event(timeout=timeout)
#     204     if isinstance(event, h11.Data):
#     205         yield bytes(event.data)
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1285, in SSLSocket.recv(self, buflen, flags)
#    1281     if flags != 0:
#    1282         raise ValueError(
#    1283             "non-zero flags not allowed in calls to recv() on %s" %
#    1284             self.__class__)
# -> 1285     return self.read(buflen)
#    1286 else:
#    1287     return super().recv(buflen, flags)
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1140, in SSLSocket.read(self, len, buffer)
#    1138         return self._sslobj.read(len, buffer)
#    1139     else:
# -> 1140         return self._sslobj.read(len)
#    1141 except SSLError as x:
#    1142     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
from langchain_nvidia_ai_endpoints import ChatNVIDIA


client = ChatNVIDIA(
  model="mistralai/mistral-medium-3.5-128b",

  temperature=0.2,
  top_p=0.7,
  max_completion_tokens=512,
)
# Out:
# c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_nvidia_ai_endpoints\_common.py:250: UserWarning: Found mistralai/mistral-medium-3.5-128b in available_models, but type is unknown and inference may fail.
#   warnings.warn(

# %%
client.invoke("What is AI?")
# Out:
# AIMessage(content='**Artificial Intelligence (AI)** is a branch of computer science that focuses on creating systems capable of performing tasks that typically require human intelligence. These tasks include:\n\n- **Learning** (e.g., recognizing patterns in data)\n- **Reasoning** (e.g., solving problems logically)\n- **Perception** (e.g., understanding images or speech)\n- **Decision-making** (e.g., choosing the best action in a game)\n- **Natural Language Processing (NLP)** (e.g., understanding and generating human language)\n\n### **Types of AI:**\n1. **Narrow AI (Weak AI)** – Designed for specific tasks (e.g., chatbots, recommendation systems).\n2. **General AI (Strong AI)** – Hypothetical AI with human-like cognitive abilities (not yet achieved).\n3. **Superintelligent AI** – AI surpassing human intelligence (theoretical).\n\n### **How AI Works:**\n- **Machine Learning (ML):** AI systems learn from data using algorithms (e.g., neural networks).\n- **Deep Learning:** A subset of ML using layered neural networks for complex tasks (e.g., image recognition).\n- **Rule-Based Systems:** AI follows predefined rules (e.g., expert systems).\n\n### **Applications of AI:**\n- **Virtual Assistants** (Siri, Alexa)\n- **Autonomous Vehicles** (Self-driving cars)\n- **Healthcare** (Diagnosis, drug discovery)\n- **Finance** (Fraud detection, trading)\n- **Entertainment** (Recommendation engines like Netflix)\n\n### **Ethical Considerations:**\n- **Bias in AI** (If trained on biased data, AI can reinforce discrimination)\n- **Job Displacement** (Automation may replace certain jobs)\n- **Privacy Concerns** (AI can analyze personal data in invasive ways)\n\nWould you like a deeper dive into any specific aspect of AI?', additional_kwargs={}, response_metadata={'role': 'assistant', 'content': '**Artificial Intelligence (AI)** is a branch of computer science that focuses on creating systems capable of performing tasks that typically require human intelligence. These tasks include:\n\n- **Learning** (e.g., recognizing patterns in data)\n- **Reasoning** (e.g., solving problems logically)\n- **Perception** (e.g., understanding images or speech)\n- **Decision-making** (e.g., choosing the best action in a game)\n- **Natural Language Processing (NLP)** (e.g., understanding and generating human language)\n\n### **Types of AI:**\n1. **Narrow AI (Weak AI)** – Designed for specific tasks (e.g., chatbots, recommendation systems).\n2. **General AI (Strong AI)** – Hypothetical AI with human-like cognitive abilities (not yet achieved).\n3. **Superintelligent AI** – AI surpassing human intelligence (theoretical).\n\n### **How AI Works:**\n- **Machine Learning (ML):** AI systems learn from data using algorithms (e.g., neural networks).\n- **Deep Learning:** A subset of ML using layered neural networks for complex tasks (e.g., image recognition).\n- **Rule-Based Systems:** AI follows predefined rules (e.g., expert systems).\n\n### **Applications of AI:**\n- **Virtual Assistants** (Siri, Alexa)\n- **Autonomous Vehicles** (Self-driving cars)\n- **Healthcare** (Diagnosis, drug discovery)\n- **Finance** (Fraud detection, trading)\n- **Entertainment** (Recommendation engines like Netflix)\n\n### **Ethical Considerations:**\n- **Bias in AI** (If trained on biased data, AI can reinforce discrimination)\n- **Job Displacement** (Automation may replace certain jobs)\n- **Privacy Concerns** (AI can analyze personal data in invasive ways)\n\nWould you like a deeper dive into any specific aspect of AI?', 'refusal': None, 'annotations': None, 'audio': None, 'function_call': None, 'tool_calls': [], 'reasoning': None, 'token_usage': {'prompt_tokens': 19, 'total_tokens': 409, 'completion_tokens': 390, 'prompt_tokens_details': None}, 'finish_reason': 'stop', 'model_name': 'mistralai/mistral-medium-3.5-128b'}, id='lc_run--019eb4f5-5493-73a0-bb5e-01c5cb9e7ef6-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 19, 'output_tokens': 390, 'total_tokens': 409}, ro ...
