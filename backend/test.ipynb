# %%
from langchain_openrouter import ChatOpenRouter
from langchain_nvidia_ai_endpoints import ChatNVIDIA
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
base_llm = ChatOpenRouter(
        model="openai/gpt-oss-120b:free",
        temperature=0.3,
    )
base_llm.invoke("What is AI?")
# Out:
# ---------------------------------------------------------------------------
# ServiceUnavailableResponseError           Traceback (most recent call last)
# Cell In[4], line 5
#       1 base_llm = ChatOpenRouter(
#       2         model="openai/gpt-oss-120b:free",
#       3         temperature=0.3,
#       4     )
# ----> 5 base_llm.invoke("What is AI?")
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
#     476                 stop=stop,
#     477                 callbacks=config.get("callbacks"),
#     478                 tags=config.get("tags"),
#     479                 metadata=config.get("metadata"),
#     480                 run_name=config.get("run_name"),
#     481                 run_id=config.pop("run_id", None),
#     482                 **kwargs,
#     483             ).generations[0][0],
#     484         ).message,
#     485     )
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:1823, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1814 @override
#    1815 def generate_prompt(
#    1816     self,
#    (...)   1820     **kwargs: Any,
#    1821 ) -> LLMResult:
#    1822     prompt_messages = [p.to_messages() for p in prompts]
# -> 1823     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:1630, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1627 for i, m in enumerate(input_messages):
#    1628     try:
#    1629         results.append(
# -> 1630             self._generate_with_cache(
#    1631                 m,
#    1632                 stop=stop,
#    1633                 run_manager=run_managers[i] if run_managers else None,
#    1634                 **kwargs,
#    1635             )
#    1636         )
#    1637     except BaseException as e:
#    1638         if run_managers:
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:1970, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1968     result = generate_from_stream(iter(chunks))
#    1969 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1970     result = self._generate(
#    1971         messages, stop=stop, run_manager=run_manager, **kwargs
#    1972     )
#    1973 else:
#    1974     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_openrouter\chat_models.py:510, in ChatOpenRouter._generate(self, messages, stop, run_manager, **kwargs)
#     508 _strip_internal_kwargs(params)
#     509 sdk_messages = _wrap_messages_for_sdk(message_dicts)
# --> 510 response = self.client.chat.send(messages=sdk_messages, **params)
#     511 return self._create_chat_result(response)
#
# File c:\Users\akshi\AppData\Local\Programs\Python\Python313\Lib\site-packages\openrouter\chat.py:652, in Chat.send(self, messages, http_referer, x_open_router_title, x_open_router_categories, cache_control, debug, frequency_penalty, image_config, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, model, models, parallel_tool_calls, plugins, presence_penalty, provider, reasoning, response_format, seed, service_tier, session_id, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, trace, user, retries, server_url, timeout_ms, http_headers)
#     648     http_res_text = utils.stream_to_text(http_res)
#     649     response_data = unmarshal_json_response(
#     650         errors.ServiceUnavailableResponseErrorData, http_res, http_res_text
#     651     )
# --> 652     raise errors.ServiceUnavailableResponseError(
#     653         response_data, http_res, http_res_text
#     654     )
#     655 if utils.match_response(http_res, "524", "application/json"):
#     656     http_res_text = utils.stream_to_text(http_res)
#
# ServiceUnavailableResponseError: Provider returned error

# %%
from langchain_nvidia_ai_endpoints import ChatNVIDIA


client = ChatNVIDIA(
  model="mistralai/mistral-medium-3.5-128b",

  temperature=0.2,
  top_p=0.7,
  max_completion_tokens=512,
)

# %%
client.invoke("What is AI?")
# Out:
# AIMessage(content='**Artificial Intelligence (AI)** is a field of computer science that focuses on creating systems capable of performing tasks that typically require human intelligence. These tasks include:\n\n- **Learning** (e.g., recognizing patterns in data)\n- **Reasoning** (e.g., solving problems logically)\n- **Perception** (e.g., understanding images or speech)\n- **Decision-making** (e.g., choosing the best action in a game)\n- **Language understanding** (e.g., chatbots like me)\n\n### **Types of AI:**\n1. **Narrow AI (Weak AI)** – Designed for specific tasks (e.g., Siri, self-driving cars).\n2. **General AI (Strong AI)** – Hypothetical AI with human-like cognitive abilities (not yet achieved).\n3. **Superintelligent AI** – AI surpassing human intelligence (still theoretical).\n\n### **How AI Works:**\n- **Machine Learning (ML):** AI systems learn from data (e.g., predicting trends).\n- **Deep Learning:** Uses neural networks to process complex data (e.g., image recognition).\n- **Natural Language Processing (NLP):** Enables AI to understand and generate human language (e.g., chatbots).\n\n### **Applications of AI:**\n- **Healthcare** (disease diagnosis, drug discovery)\n- **Finance** (fraud detection, algorithmic trading)\n- **Transportation** (autonomous vehicles)\n- **Entertainment** (recommendation systems like Netflix)\n- **Robotics** (industrial automation)\n\n### **Ethical Concerns:**\n- **Bias in AI** (if trained on biased data)\n- **Job displacement** (automation replacing human jobs)\n- **Privacy issues** (data collection and misuse)\n\nAI is rapidly evolving, with both exciting possibilities and challenges. Would you like a deeper dive into any specific aspect?', additional_kwargs={}, response_metadata={'role': 'assistant', 'content': '**Artificial Intelligence (AI)** is a field of computer science that focuses on creating systems capable of performing tasks that typically require human intelligence. These tasks include:\n\n- **Learning** (e.g., recognizing patterns in data)\n- **Reasoning** (e.g., solving problems logically)\n- **Perception** (e.g., understanding images or speech)\n- **Decision-making** (e.g., choosing the best action in a game)\n- **Language understanding** (e.g., chatbots like me)\n\n### **Types of AI:**\n1. **Narrow AI (Weak AI)** – Designed for specific tasks (e.g., Siri, self-driving cars).\n2. **General AI (Strong AI)** – Hypothetical AI with human-like cognitive abilities (not yet achieved).\n3. **Superintelligent AI** – AI surpassing human intelligence (still theoretical).\n\n### **How AI Works:**\n- **Machine Learning (ML):** AI systems learn from data (e.g., predicting trends).\n- **Deep Learning:** Uses neural networks to process complex data (e.g., image recognition).\n- **Natural Language Processing (NLP):** Enables AI to understand and generate human language (e.g., chatbots).\n\n### **Applications of AI:**\n- **Healthcare** (disease diagnosis, drug discovery)\n- **Finance** (fraud detection, algorithmic trading)\n- **Transportation** (autonomous vehicles)\n- **Entertainment** (recommendation systems like Netflix)\n- **Robotics** (industrial automation)\n\n### **Ethical Concerns:**\n- **Bias in AI** (if trained on biased data)\n- **Job displacement** (automation replacing human jobs)\n- **Privacy issues** (data collection and misuse)\n\nAI is rapidly evolving, with both exciting possibilities and challenges. Would you like a deeper dive into any specific aspect?', 'refusal': None, 'annotations': None, 'audio': None, 'function_call': None, 'tool_calls': [], 'reasoning': None, 'token_usage': {'prompt_tokens': 19, 'total_tokens': 405, 'completion_tokens': 386, 'prompt_tokens_details': None}, 'finish_reason': 'stop', 'model_name': 'mistralai/mistral-medium-3.5-128b'}, id='lc_run--019e8bf9-3c62-73b1-a7b9-90e95a33545d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 19, 'output_tokens': 386, 'total_tokens': 405}, role='assistant')
